# %%
#tekst do analizy
text = """
Python jest bardzo wszechstronnym językiem programowania.
Jest używany w analizie danych, uczeniu maszynowym i wielu innych dzidzinach.
Czy warto się uczyć?
"""

# %%
#statystyki
char_count = len(text)
char_count
# Out:
# 158

# %%
word_count = len(text.split())
word_count
# Out:
# 21

# %%
sentence_count = text.count('.') + text.count('!') + text.count('?')
sentence_count
# Out:
# 3

# %%
#znaki bez whitespaces
bs = len(text) - text.count(' ')
bs
# Out:
# 140

# %%
nowytext = str(text)
liczba_znakow = len(nowytext.replace(" ","").replace("\n",""))
liczba_znakow
# Out:
# 136

# %%
p = nowytext.replace(" ","").replace("\n","")

# %%
nowytext
# Out:
# '\nPython jest bardzo wszechstronnym językiem programowania.\nJest używany w analizie danych, uczeniu maszynowym i wielu innych dzidzinach.\nCzy warto się uczyć?\n'

# %%
p
# Out:
# 'Pythonjestbardzowszechstronnymjęzykiemprogramowania.Jestużywanywanaliziedanych,uczeniumaszynowymiwieluinnychdzidzinach.Czywartosięuczyć?'
